# %% [markdown]
# # Get stats on selected words

# %%
# %run -i 'vittorio.py'
# Out:
# Which word would you like to have stats on? Comma-separated list, ex: "Trump, Biden" (leave empty to have full stats)
# Trump, Biden, Car

# %% [markdown]
# # Get stats on 20 most liked words

# %%
# %run -i 'vittorio.py' 20 first 1
# Out:
# Which word would you like to have stats on? Comma-separated list, ex: "Trump, Biden" (leave empty to have full stats)
#
# Processing 8741 words...

# %% [markdown]
# # Get stats on 20 least liked words

# %%
# %run -i 'vittorio.py' 20 last 1
# Out:
# Which word would you like to have stats on? Comma-separated list, ex: "Trump, Biden" (leave empty to have full stats)
#
# Processing 8741 words...

# %% [markdown]
# # Get stats on 300 most liked words, steped each 20th

# %%
# %run -i 'vittorio.py' 300 first 20
# Out:
# Which word would you like to have stats on? Comma-separated list, ex: "Trump, Biden" (leave empty to have full stats)
#
# Processing 8741 words...

# %% [markdown]
# # Get stats on 300 least liked words, stepped each 20th

# %%
# %run -i 'vittorio.py' 300 last 20
# Out:
# Which word would you like to have stats on? Comma-separated list, ex: "Trump, Biden" (leave empty to have full stats)
#
# Processing 8741 words...
