# %%
# %run -i 'vittorio2.py'
# Out:
# Which word would you like to have stats on? Comma-separated list, ex: "Trump, Biden" (leave empty to have full stats)
# trump, johnson
# AxesSubplot(0.125,0.125;0.775x0.755)
# --- 2 words proceeded in 0.07803678512573242 seconds ---
