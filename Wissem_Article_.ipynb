# %%
import pandas as pd

# %%
df = pd.read_csv("articles_data.csv", index_col='index')

# %%
#Ajouter une colonne pour la taille de l'article 
df['article_length']= df['content'].str.len()

# %%
#calculer le total des commentaires shares et likes
df['reactions_count'] = df['engagement_reaction_count'] + df['engagement_comment_count'] + df['engagement_share_count']

# %%
df.sort_values(['article_length','reactions_count'], ascending=[False, False])
# Out:
#                 source_id         source_name           author  \
# index
# 6685             newsweek            Newsweek    James LaPorta
# 8654             abc-news            ABC News  Bill Hutchinson
# 8685             cbs-news            CBS News         CBS News
# 6225             cbs-news            CBS News         CBS News
# 10131  the-new-york-times  The New York Times              NaN
# ...                   ...                 ...              ...
# 10411            cbs-news            CBS News         CBS News
# 10430            cbs-news            CBS News         CBS News
# 10435            cbs-news            CBS News         CBS News
# 10436            cbs-news            CBS News         CBS News
# 750                     1               460.0            151.0
#
#                                                    title  \
# index
# 6685   Exclusive: Two Afghanistan Veterans, Would-Be ...
# 8654   More than 30,000 children under age 10 have be...
# ...

# %%
df[''article_length','reactions_count'']
